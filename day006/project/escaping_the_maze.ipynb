# %% [markdown]
# ## maze

# %%
def turn_right():
    turn_left()
    turn_left()
    turn_left()

while front_is_clear():
    move()
turn_left()


while not at_goal():
    if right_is_clear():
        turn_right()
        move()
    if front_is_clear():
        move()
    else:
        turn_left()

# %% [markdown]
# ## outputs

# %%
from IPython.display import Image

display(Image(filename='maze1.png', width = 300)) 
display(Image(filename='maze2.png', width = 300)) 
display(Image(filename='maze3.png', width = 300)) 
display(Image(filename='maze4.png', width = 300))
